# %%
import pandas as pd
data={'apple':[3,2,0,1],'oranges':[0,3,7,2]}
df=pd.DataFrame(data,index=['a','b','c','d'])
df

# %%
import pandas as pd
data = {
    "id": [101, 102, 103, 104],
    "name": ["Rahul", "Vikas", "Neelesh", "Kiran"],
    "branch": ["CSE", "ECE", "AIDS", "CSIT"],
    "section": ["s1", "s2", "s1", "s2"]
}
df = pd.DataFrame(data,index=['A','B','C','D'])
df.to_csv('new_dataset.csv')
df.to_json('new_dataset1.csv')
#df.loc['B']

# %%
import pandas as pd
df = pd.read_csv("tips.csv")
df

# %%
import pandas as pd
df=pd.read_csv('movies.csv',index_col='title')
#df.info() #to know what are the columns names and which datatypes the info is
#df.describe  #to know
df.shape #to know how many rows and columns in dataset
#df.head(10) #to know top number rows of movies
#df.tail(2)  #to know last number row of movies
temp_df=df.drop_duplicates()
temp_df.shape
# Out:
# (4803, 23)

# %%
df=pd.read_csv('movies.csv')
x=pd.concat([df,df])
x.drop_duplicates(inplace=True)
x.shape
# Out:
# (4803, 24)

# %%
import pandas as pd

d1 = [
    {'a': 1, 'b': 2},
    {'a': 5, 'b': 10, 'c': 20}
]

df1 = pd.DataFrame(d1, index=['first', 'second'], columns=['a', 'b'])
df2 = pd.DataFrame(d1, index=['first', 'second'], columns=['a', 'b1'])

print(df1)
print('............')
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
# ............
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
import pandas as pd
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])
  }
df=pd.DataFrame(d)
print("Adding a new column by passing as Series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print("Adding a new column using the existing columns in DataFrame:")
df['four']=df['one']+df['three']
print(df)
# Out:
# Adding a new column by passing as Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
import pandas as pd
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])
  }
df=pd.DataFrame(d)
print("Our dataframe is:")
print(df)
print("Deleting the first column using DEL function:")
del df['one']
print(df)
print("Deleting another column using POP function:")
df.pop('two')
print(df)
print(df[1:4])
# Out:
# Our dataframe is:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# Deleting the first column using DEL function:
#    two
# a    1
# b    2
# c    3
# d    4
# Deleting another column using POP function:
# Empty DataFrame
# Columns: []
# Index: [a, b, c, d]
# Empty DataFrame
# Columns: []
# Index: [b, c, d]

# %%
import pandas as pd
d={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])
  }
df=pd.DataFrame(d)
print(df[3:4])
# Out:
#    one  two
# d  NaN    4

# %%
import pandas as pd

df1 = pd.DataFrame({
    "A":[1,5,3,4,2],
    "B":[3,2,4,3,4],
    "C":[2,2,7,3,4],
    "D":[4,3,6,12,7]
}, index=["A1","A2","A3","A4","A5"])

df2 = pd.DataFrame({
    "A":[1,5,3,4,2],
    "B":[3,2,4,3,4],
    "C":[2,2,7,3,4],
    "D":[4,3,6,12,7]
}, index=["A1","A2","A3","A4","A5"])

print(df1.reindex_like(df2))
# Out:
#     A  B  C   D
# A1  1  3  2   4
# A2  5  2  2   3
# A3  3  4  7   6
# A4  4  3  3  12
# A5  2  4  4   7

# %%
import pandas as pd
df=pd.read_csv("movies.csv")
total_nans=df.isna().sum().sum()
nans_per_columns=df.isna().sum()
print("Total Nans:",total_nans)
print("NANS per column:",nans_per_columns)
# Out:
# Total Nans: 4454
# NANS per column: index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
df.dropna()#droping null values

# %%
df.dropna(axis=1)#dropiing null values from colum

# %%
df.shape
# Out:
# (4803, 24)

# %%
df.fillna(0)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'budget': [1000, 2000, np.nan,1000]
})

df['budget'].fillna(df['budget'].mean(), inplace=True)#in place of mean we can use median and mode also

print(df)

# %%
df_ffill = df.copy()
df_ffill.fillna(method='ffill', inplace=True)
print(df_ffill)
# Out:
#         budget
# 0  1000.000000
# 1  2000.000000
# 2  1333.333333
# 3  1000.000000
# /tmp/ipykernel_1113/3989740104.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill', inplace=True)

# %%
df_bfill = df.copy()
df_bfill.fillna(method='bfill', inplace=True)
print(df_bfill)
# Out:
#         budget
# 0  1000.000000
# 1  2000.000000
# 2  1333.333333
# 3  1000.000000
# /tmp/ipykernel_1113/3163818295.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill.fillna(method='bfill', inplace=True)

# %%
import pandas as pd

# Sample dataset with inconsistent date formats
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})

# Convert all dates to standard ISO format (YYYY-MM-DD)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})

# Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()
print(df)

# Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower
# 0    Alice      alice
# 1      BOB        bob
# 2  charlie    charlie
# 3    DAVID      david
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
df=pd.read_csv("movies.csv")
df['Name_lower']=df['director'].str.lower()
print(df)
df['Name_upper']=df['director'].str.upper()
print(df.head(10))
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...
